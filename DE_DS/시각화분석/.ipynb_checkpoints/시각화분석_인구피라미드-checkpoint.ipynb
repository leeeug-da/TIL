# %% [markdown]
# # 인구 피라미드 👨‍👨‍👧‍👧

# %% [markdown]
# **데이터 출처**
# - 출처 : 행정안전부 주민등록 인구 통계 (공공데이터)
# - https://jumin.mois.go.kr/ageStatMonth.do#none
#
# <br/>
#
# **데이터 설명**
# - 2013년 10월 ~ 2023년 10월 / 전국 / 남여 인구 통계수와 10년간의 변화를 확인합니다.

# %% [markdown]
# ## 🗂️ 라이브러리

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상 방지

# %% [markdown]
# ## 💁‍♀️ 2013년 데이터

# %% [markdown]
# ### 📍 남자 데이터

# %%
# 데이터 불러오기
df_m = pd.read_excel('./data/201310_201310_연령별인구현황_월간.xlsx', skiprows=3, 
              index_col='행정기관', usecols='B, E:Y')
df_m.head(3)
# Out:
# /Users/euijinlee/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,184,828  1,203,305  1,477,993  1,809,294  1,797,463  1,655,812
# 서울특별시      210,620    207,281    252,695    322,230    350,085    383,140
# 부산광역시       68,329     67,661     88,354    118,825    129,090    113,264
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       2,088,503  2,018,372  2,341,763  2,174,225  ...  1,787,726
# 서울특별시      477,886    416,712    461,284    405,996  ...    355,936
# 부산광역시      139,002    126,487    145,894    140,481  ...    146,530
#
#             60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세  \
# ...

# %%
# str -> int
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int)
df_m.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       1184828  1203305  1477993  1809294  1797463  1655812  2088503
# 서울특별시    210,620  207,281  252,695  322,230  350,085  383,140  477,886
# 부산광역시     68,329   67,661   88,354  118,825  129,090  113,264  139,002
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       2018372  2341763  2174225  ...  1787726  1214090   932562   797962
# 서울특별시    416,712  461,284  405,996  ...  355,936  250,212  197,943  159,470
# 부산광역시    126,487  145,894  140,481  ...  146,530  105,669   78,215   63,061
#
#          75~79세  80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국       497303  226220   85105  28567   5441    3160
# 서울특별시    86,974  37,638  14,438  5,800  1,311   1,086
# 부산광역시    34,372  14,597   4,909  1,502    277     274
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 📍 여자 데이터

# %%
# 데이터 불러오기
df_w = pd.read_excel('./data/201310_201310_연령별인구현황_월간.xlsx', skiprows=3,
                    index_col='행정기관', usecols='B, AB:AV')
df_w.head(3)
# Out:
# /Users/euijinlee/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,118,666  1,125,988  1,354,195  1,624,314  1,599,130  1,543,378
# 서울특별시      199,519    195,417    234,411    294,291    342,223    392,716
# 부산광역시       64,729     63,518     79,839    103,542    112,271    106,090
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       2,002,033  1,941,224  2,250,610  2,100,674  ...  1,787,032
# 서울특별시      471,407    407,529    455,712    409,859  ...    384,142
# 부산광역시      133,324    121,860    146,119    145,886  ...    153,905
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# ...

# %%
# str -> int
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int)
df_w.head(3)
# Out:
#           0~4세.1   5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1  \
# 행정기관
# 전국       1118666  1125988  1354195  1624314  1599130  1543378  2002033
# 서울특별시    199,519  195,417  234,411  294,291  342,223  392,716  471,407
# 부산광역시     64,729   63,518   79,839  103,542  112,271  106,090  133,324
#
#         35~39세.1 40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1  \
# 행정기관                                ...
# 전국       1941224  2250610  2100674  ...  1787032  1265018  1034234  1008583
# 서울특별시    407,529  455,712  409,859  ...  384,142  270,761  218,188  178,174
# 부산광역시    121,860  146,119  145,886  ...  153,905  112,378   84,944   76,209
#
#         75~79세.1 80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국        760853   473425   232322    91226    21203     10465
# 서울특별시    118,781   71,985   38,256   15,583    4,289     3,129
# 부산광역시     51,435   30,951   15,361    5,156    1,226     1,012
#
# [3 rows x 21 columns]

# %%
# column명 통일 
df_w.columns = df_m.columns
df_w.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국       1118666  1125988  1354195  1624314  1599130  1543378  2002033
# 서울특별시    199,519  195,417  234,411  294,291  342,223  392,716  471,407
# 부산광역시     64,729   63,518   79,839  103,542  112,271  106,090  133,324
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       1941224  2250610  2100674  ...  1787032  1265018  1034234  1008583
# 서울특별시    407,529  455,712  409,859  ...  384,142  270,761  218,188  178,174
# 부산광역시    121,860  146,119  145,886  ...  153,905  112,378   84,944   76,209
#
#           75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국        760853  473425  232322   91226  21203   10465
# 서울특별시    118,781  71,985  38,256  15,583  4,289   3,129
# 부산광역시     51,435  30,951  15,361   5,156  1,226   1,012
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 📍 시각화 (막대 그래프)

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # 남자 데이터 # 단위 : 천명
plt.barh(df_w.columns, df_m.iloc[0] // 1000) # 여자 데이터 # 단위 : 천명
plt.title('2013년 대한민국 인구 피라미드')
plt.savefig('2013_인구피라미드.png', dpi=100)
plt.show()

# %% [markdown]
# ## 💁‍♀️ 2023년 데이터

# %% [markdown]
# ### 📍 남자 데이터

# %%
# 데이터 불러오기
df_m_23 = pd.read_excel('./data/202310_202310_연령별인구현황_월간.xlsx', skiprows=3,
                       index_col='행정기관', usecols=('B, E:Y'))
df_m_23
# Out:
# /Users/euijinlee/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         690,593  1,032,949  1,200,375  1,199,785  1,465,739  1,792,090
# 서울특별시      110,832    155,105    182,895    194,243    263,138    384,934
# 부산광역시       39,084     61,649     68,900     66,490     89,569    105,955
# 대구광역시       29,897     47,746     54,734     56,204     71,256     78,966
# 인천광역시       42,550     61,502     70,595     68,949     83,487    106,412
# 광주광역시       20,025     31,579     37,726     38,677     47,867     52,563
# 대전광역시       20,605     29,578     34,871     36,682     47,235     57,655
# 울산광역시       15,525     25,570     29,144     28,007     31,337     38,625
# ...

# %%
# str -> int
df_m_23.iloc[0] = df_m_23.iloc[0].str.replace(',', '').astype(int)
df_m_23.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국        690593  1032949  1200375  1199785  1465739  1792090  1781392
# 서울특별시    110,832  155,105  182,895  194,243  263,138  384,934  389,464
# 부산광역시     39,084   61,649   68,900   66,490   89,569  105,955  105,667
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       1640985  2062533  1981687  ...  2084607  2113976  1637345  1059314
# 서울특별시    324,772  365,832  339,776  ...  340,247  342,086  281,725  190,751
# 부산광역시     96,381  127,240  118,626  ...  127,320  141,445  123,560   84,868
#
#           75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국        747180  519954  225928   57955   9348    1483
# 서울특별시    141,601  96,979  39,328  10,065  1,800     330
# 부산광역시     58,462  38,574  14,415   3,321    473      68
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 📍 여자 데이터

# %%
# 데이터 불러오기
df_w_23 = pd.read_excel('./data/202310_202310_연령별인구현황_월간.xlsx', skiprows=3,
                       index_col='행정기관', usecols=('B, AB:AV'))
df_w_23.head(3)
# Out:
# /Users/euijinlee/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1   5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       657,269  982,751  1,135,692  1,127,418  1,351,829  1,624,383
# 서울특별시    104,426  148,147    173,025    186,683    297,593    418,667
# 부산광역시     37,114   58,557     65,285     63,199     85,113     99,901
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,609,788  1,550,406  1,991,393  1,921,347  ...  2,063,792
# 서울특별시      387,467    326,509    371,517    349,119  ...    355,959
# 부산광역시       97,781     92,338    124,523    116,557  ...    136,561
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# ...

# %%
# str -> int
df_w_23.iloc[0] = df_w_23.iloc[0].str.replace(',', '').astype(int)
df_w_23.head(3)
# Out:
#           0~4세.1   5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1  \
# 행정기관
# 전국        657269   982751  1135692  1127418  1351829  1624383  1609788
# 서울특별시    104,426  148,147  173,025  186,683  297,593  418,667  387,467
# 부산광역시     37,114   58,557   65,285   63,199   85,113   99,901   97,781
#
#         35~39세.1 40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1  \
# 행정기관                                ...
# 전국       1550406  1991393  1921347  ...  2063792  2141909  1729492  1199043
# 서울특별시    326,509  371,517  349,119  ...  355,959  372,122  322,116  225,334
# 부산광역시     92,338  124,523  116,557  ...  136,561  157,799  139,560  101,092
#
#         75~79세.1 80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국        935752   813491   480553   185375    42967      7233
# 서울특별시    176,772  131,301   69,783   26,295    6,609     1,141
# 부산광역시     73,557   58,126   29,976   10,624    2,587       369
#
# [3 rows x 21 columns]

# %%
# column 명 통일
df_w_23.columns = df_m_23.columns
df_w_23.head(3)
# Out:
#             0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국        657269   982751  1135692  1127418  1351829  1624383  1609788
# 서울특별시    104,426  148,147  173,025  186,683  297,593  418,667  387,467
# 부산광역시     37,114   58,557   65,285   63,199   85,113   99,901   97,781
#
#           35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                ...
# 전국       1550406  1991393  1921347  ...  2063792  2141909  1729492  1199043
# 서울특별시    326,509  371,517  349,119  ...  355,959  372,122  322,116  225,334
# 부산광역시     92,338  124,523  116,557  ...  136,561  157,799  139,560  101,092
#
#           75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국        935752   813491  480553  185375  42967    7233
# 서울특별시    176,772  131,301  69,783  26,295  6,609   1,141
# 부산광역시     73,557   58,126  29,976  10,624  2,587     369
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 📍 시각화 (막대 그래프)

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m_23.columns, -df_m_23.iloc[0] // 1000) # 남자 데이터 # 단위 : 1000명
plt.barh(df_w_23.columns, df_w_23.iloc[0] // 1000) # 남자 데이터 # 단위 : 1000명
plt.title('2023년 대한민국 인구 피라미드')
plt.savefig('2023_인구피라미드.png', dpi=100)
plt.show()

# %% [markdown]
# ## 📈 분석 리포트

# %% [markdown]
# ![image.png](attachment:52315468-f302-472a-aaab-7cdad45897c8.png)
# ![image.png](attachment:7ed8d4ae-9fba-4073-a412-b7963b9c9e3d.png)

# %% [markdown]
# - 남녀 성비 비율은 전체 연령 통틀어 전체적으로 비슷하나, 2023년도 노인층의 여성 비율이 더 높아짐
# - 고령화가 진행되고 있음을 확인 할 수 있음
#     - 2013년도 가장 인구가 밀집되어 있는 연령대는 '40-44세' & '50-54세' 인 것에 반해, 2023년도의 가장 인구가 밀집되어 있는 연령대는 '50-54세' & '60-64세'
#       - 2013년도의 해당 인구가 동일하게 유지되고 있으며, 2023년도의 '40-44세' & '50-54세' 구간 인구 비율이 줄어듦
#     - 어느정도의 데이터가 집계됨을 기준으로, 최고 연령대가 2013년도 '90-94세' 에서 2023년도 '95-99세'로 상향됨
#     - 2013년도 '0-4세' 인구 비율에 반해 2023년도 '0-4세' 인구 비율이 현저히 떨어지고 있음을 확인
