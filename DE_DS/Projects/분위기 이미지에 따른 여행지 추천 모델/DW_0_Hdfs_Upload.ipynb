# %% [markdown]
# ## DataWarehouse 0️⃣ | Hadoop 에 파일 Upload

# %% [markdown]
# ### Hadoop 실행

# %%
# service ssh start

# start-all.sh

# jps

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.04.45.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.04.45.png)

# %% [markdown]
# ### Hdfs 에 파일 Upload
# - travel_data : 관광지 정보 데이터

# %%
# unzip /root/note/data/travel_data.zip

# %%
# hdfs dfs -put travel_data /travel_data

# %%
# hdfs dfs -ls /travel_data

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.05.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.05.55.png)
