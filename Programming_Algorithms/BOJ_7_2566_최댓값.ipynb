# %% [markdown]
# # **BOJ 단계별로 풀어보기**
# ## **📌 7단계 | 2566번 | 최댓값**
# #### **✔️ 문제**
# <그림 1>과 같이 9×9 격자판에 쓰여진 81개의 자연수 또는 0이 주어질 때, 이들 중 최댓값을 찾고 그 최댓값이 몇 행 몇 열에 위치한 수인지 구하는 프로그램을 작성하시오.
#
# 예를 들어, 다음과 같이 81개의 수가 주어지면
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-04-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.17.43.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-04-11%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.17.43.png)
#
# 이들 중 최댓값은 90이고, 이 값은 5행 7열에 위치한다.
# #### **✔️ 입력**
# 첫째 줄부터 아홉 번째 줄까지 한 줄에 아홉 개씩 수가 주어진다. 주어지는 수는 100보다 작은 자연수 또는 0이다.
# #### **✔️ 출력**
# 첫째 줄에 최댓값을 출력하고, 둘째 줄에 최댓값이 위치한 행 번호와 열 번호를 빈칸을 사이에 두고 차례로 출력한다. 최댓값이 두 개 이상인 경우 그 중 한 곳의 위치를 출력한다.
# #### **✔️ 예제 입력 1**
# 3 23 85 34 17 74 25 52 65 <br/>
# 10 7 39 42 88 52 14 72 63 <br/>
# 87 42 18 78 53 45 18 84 53 <br/>
# 34 28 64 85 12 16 75 36 55 <br/>
# 21 77 45 35 28 75 90 76 1 <br/>
# 25 87 65 15 28 11 37 28 74 <br/>
# 65 27 75 41 7 89 78 64 39 <br/>
# 47 47 70 45 23 65 3 41 44 <br/>
# 87 13 82 38 31 12 29 29 80 <br/>
# #### **✔️ 예제 출력 1**
# 90
# 5 7

# %%
grid = []

for row in range(9):
    grid.append(list(map(int, input().split())))

max_value = 0
row = 0
col = 0

for i in range(9):
    for j in range(9):
        if grid[i][j] >= max_value:
            max_value = grid[i][j]
            row = i+1
            col = j+1

print(max_value)
print(row, col)
# Out:
# 3 23 85 34 17 74 25 52 65
# 10 7 39 42 88 52 14 72 63
# 87 42 18 78 53 45 18 84 53
# 34 28 64 85 12 16 75 36 55
# 21 77 45 35 28 75 90 76 1
# 25 87 65 15 28 11 37 28 74
# 65 27 75 41 7 89 78 64 39
# 47 47 70 45 23 65 3 41 44
# 87 13 82 38 31 12 29 29 80
# 90
# 5 7
