# %% [markdown]
# ### 출처
# - 대회 : https://www.kaggle.com/competitions/kaggle-survey-2022/data
# - 필사 스터디 : https://www.kaggle.com/code/eraikako/data-science-and-mlops-landscape-in-industry

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import numpy as np
import json
from collections import Counter

import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
from plotly.colors import n_colors

from IPython.core.display import display, HTML, Javascript 
import IPython.display
from IPython.display import display, clear_output

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

import matplotlib as mpl
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/ct/rmrw659s2kzcvrbn0b37dqsh0000gn/T/ipykernel_61497/2702317144.py:13: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display

# %% [markdown]
# #### Load Data

# %%
df = pd.read_csv('./Data/kaggle_survey_2022_responses.csv')

# %%
# 서베이 질문 따로 빼기
questions_titles = df[0:1] # 0번 행만 가져오기 
questions_titles
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
#
#                                           Q4  \
# 0  In which country do you currently reside?
#
#                                                   Q5  \
# 0  Are you currently a student? (high school, uni...
#
#                                                 Q6_1  \
# 0  On which platforms have you begun or completed...
#
#                                                 Q6_2  \
# 0  On which platforms have you begun or completed...
#
#                                                 Q6_3  \
# 0  On which platforms have you begun or completed...
#
#                                                 Q6_4  \
# 0  On which platforms have you begun or completed...
#
#                                                 Q6_5  ...  \
# 0  On which platforms have you begun or completed...  ...
#
#                                                Q44_3  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_4  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_5  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_6  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_7  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_8  \
# 0  Who/what are your favorite media sources that ...
#
#                                                Q44_9  \
# 0  Who/what are your favorite media sources that ...
#
#                                               Q44_10  \
# 0  Who/what are your favorite media sources that ...
#
#                                               Q44_11  \
# 0  Who/what are your favorite media sources that ...
#
#                                               Q44_12
# 0  Who/what are your favorite media sources that ...
#
# [1 rows x 296 columns]

# %%
# 서베이 답변으로만 데이터 구성
df = df[1:]
df.head()
# Out:
#   Duration (in seconds)     Q2   Q3       Q4   Q5      Q6_1 Q6_2  \
# 1                   121  30-34  Man    India   No       NaN  NaN
# 2                   462  30-34  Man  Algeria   No       NaN  NaN
# 3                   293  18-21  Man    Egypt  Yes  Coursera  edX
# 4                   851  55-59  Man   France   No  Coursera  NaN
# 5                   232  45-49  Man    India  Yes       NaN  NaN
#
#                    Q6_3      Q6_4 Q6_5  ... Q44_3  \
# 1                   NaN       NaN  NaN  ...   NaN
# 2                   NaN       NaN  NaN  ...   NaN
# 3                   NaN  DataCamp  NaN  ...   NaN
# 4  Kaggle Learn Courses       NaN  NaN  ...   NaN
# 5                   NaN       NaN  NaN  ...   NaN
#
#                              Q44_4  \
# 1                              NaN
# 2                              NaN
# 3  Kaggle (notebooks, forums, etc)
# 4  Kaggle (notebooks, forums, etc)
# 5                              NaN
#
#                                                Q44_5  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Course Forums (forums.fast.ai, Coursera forums...
# 5                                                NaN
#
#                                                Q44_6  \
# 1                                                NaN
# 2                                                NaN
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                NaN
# 5                                                NaN
#
#                                                Q44_7  \
# 1                                                NaN
# 2                                                NaN
# 3  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 4                                                NaN
# 5                                                NaN
#
#                                                Q44_8 Q44_9 Q44_10 Q44_11  \
# 1                                                NaN   NaN    NaN    NaN
# 2                                                NaN   NaN    NaN    NaN
# 3                                                NaN   NaN    NaN    NaN
# 4  Blogs (Towards Data Science, Analytics Vidhya,...   NaN    NaN    NaN
# 5  Blogs (Towards Data Science, Analytics Vidhya,...   NaN    NaN    NaN
#
#   Q44_12
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
#
# [5 rows x 296 columns]

# %% [markdown]
# #### Visualization 함수

# %%
def wrap_df_text(df):
    return display(HTML(df.style.background_gradient(axis=0,  cmap='YlOrBr', subset=["Average number of selected choices"]).to_html().replace("\\n","<br>")))

# %% [markdown]
# ### 종사자 구분
#
# - Q5 질문(Are you currently a student?)에 'No'라고 응답
# - Q23 질문(Select the title most similar to your current role)에 'Currently not employed'을 제외한 나머지 선택지에서 응답
# - Q24 질문(In what industry is your current employer/contract?)에 응답

# %%
scope_df = df[
    (df["Q5"] == "No") &
    (df["Q23"] != "Currently not employed") &
    (df["Q5"].notnull())
]

# %% [markdown]
# ## 이상치 / 평균 응답 수
#
# - 이 데이터셋에서 '이상치'의 정의 = multiple choice 모든 선택지에 체크 표시한 사람

# %% [markdown]
# 1. multiple choice 질문 & 선택지 항목 수

# %%
multiple_choice_questions = {} #multiple_choice 질문과 선택지 개수를 저장할 딕셔너리
seen_columns = [] #이미 처리한 질문을 기록하는 리스트

for col in df.columns: #각 컬럼 순회 
    question = col.split("_")[0] #예시: 'Q6_1' -> 'Q6' 부분을 질문으로 간주
    
    # 이미 처리된 질문이라면
    if question in seen_columns:
        
        ## 처음 추가하는 질문이라면
        if question not in multiple_choice_questions: 
            multiple_choice_questions[question] = 2 #선택지 개수 2로 설정 (기본적으로 2개의 선택지 존재)
        
        ## 이미 있는 질문이라면
        else: 
            multiple_choice_questions[question] = multiple_choice_questions[question] + 1 #선택지 개수 1 증가
    else:
        seen_columns.append(question)

# %%
multiple_choice_questions
# Out:
# {'Q6': 12,
#  'Q7': 7,
#  'Q10': 3,
#  'Q12': 15,
#  'Q13': 14,
#  'Q14': 16,
#  'Q15': 15,
#  'Q17': 15,
#  'Q18': 14,
#  'Q19': 8,
#  'Q20': 6,
#  'Q21': 10,
#  'Q28': 8,
#  'Q31': 12,
#  'Q33': 5,
#  'Q34': 8,
#  'Q35': 16,
#  'Q36': 15,
#  'Q37': 13,
#  'Q38': 8,
#  'Q39': 12,
#  'Q40': 15,
#  'Q41': 9,
#  'Q42': 9,
#  'Q44': 12}

# %% [markdown]
# 2. 응답 수 계산 함수

# %%
def extract_the_number_of_responses(question_title : str, #질문명 (Q1, Q2 등)
                                    row : pd.Series, # 위 질문에 대한 응답자 데이터 확인 (행)
                                    columns_list : list) #질문명에 대한 모든 컬럼 확인 (Q1_A, Q1_B 등)
                                    -> str: #왜 str로 반환??
    
    num_responses = 0  #선택지 개수 저장 변수 초기화
    for col in columns_list:  #모든 컬럼을 하나씩 순회
        if col.startswith(question_title):  #현재 컬럼이 주어진 질문에 해당하는지
            if not pd.isnull(row[col]):  #결측치가 아닌 경우만 응답으로 간주
                num_responses = num_responses +1  #응답 개수를 1씩 증가
    return num_responses #응답 개수 반환

# %% [markdown]
# 3. 응답 수 df에 추가

# %%
# 각 질문(col)에 대해 반복 실행
for col in list(multiple_choice_questions.keys()): #keys = 질문명 (e.g. Q1, Q2) 
    
    # 각 질문에 대한 새로운 열 생성 (e.g. Q1_number_of_responses)
    scope_df[f"{col}_number_of_responses"] = scope_df.apply(
        
        # col : "Q1" 일때
        # df.columns : 이에 해당하는 모든 컬럼을 확인하고(Q1_A, Q1_B 등)
        # x : 응답자가 선택한 항목(결측치가 아닌)의 개수를 반환 
        # axis = 1 : 함수가 행 단위로 적용되게 함 
        lambda x : extract_the_number_of_responses(col,x,df.columns),
                                                   axis = 1)

# %% [markdown]
# 4. 이상치 / 평균 응답 수 확인

# %%
# 빈리스트 생성
outlier_analysis = []

for col in list(multiple_choice_questions.keys()):
    mean_responses = round(scope_df[f"{col}_number_of_responses"].mean()) #응답 평균 수 계산
    #리스트에 추가 
    outlier_analysis.append([
        col,  #질문
        multiple_choice_questions[col],  #선택지 개수
        mean_responses,   #평균 응답 수
    ])

# %%
# 데이터 프레임 생성 
average_responses = pd.DataFrame(outlier_analysis,
                                columns = ["Question",
                                           "Nbr of available Choices",
                                           "Average number of selected choices"])

# %%
# 컬럼 추가 - 질문 제목
average_responses["Question Title"] = questions_titles[
    [f"{col}_1" for col in list(multiple_choice_questions.keys())]
    ].loc[0].to_list()
## 질문에 "Select 어쩌구" 있을 때 "Select 제거"
average_responses["Question Title"] = average_responses[
    "Question Title"].apply(lambda x : x.split("(Select")[0].strip())


# scope_df에서 {col}_number_of_respones 컬럼 삭제인데 왜 삭제해야 되는지는 모르겠음
# average_responses 데이터 프레임으로 새로 만들었는데 (?)
scope_df.drop([f"{col}_number_of_responses" for col in list(multiple_choice_questions.keys())],
             axis=1, inplace=True)

# 질문 제목의 텍스트를 '80자' 기준으로 줄 바꿈 처리 
average_responses["Question Title"] = average_responses['Question Title'].str.wrap(80)

# 데이터 프레임 열 순서 재정렬
average_responses = average_responses[["Question",
                                      "Question Title",
                                      "Nbr of available Choices",
                                      "Average number of selected choices"]]
wrap_df_text(average_responses)
# Out:
# <style type="text/css">
# #T_1890d_row0_col3, #T_1890d_row1_col3, #T_1890d_row3_col3, #T_1890d_row4_col3, #T_1890d_row6_col3, #T_1890d_row7_col3, #T_1890d_row8_col3, #T_1890d_row12_col3, #T_1890d_row24_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_1890d_row2_col3, #T_1890d_row10_col3, #T_1890d_row14_col3, #T_1890d_row19_col3, #T_1890d_row20_col3, #T_1890d_row22_col3, #T_1890d_row23_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1890d_row5_col3, #T_1890d_row9_col3, #T_1890d_row11_col3, #T_1890d_row13_col3, #T_1890d_row15_col3, #T_1890d_row16_col3, #T_1890d_row17_col3, #T_1890d_row18_col3, #T_1890d_row21_col3 {
#   background-color: #fe9829;
#   color: #000000;
# }
# </style>
# <table id="T_1890d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1890d_level0_col0" class="col_heading level0 col0" >Question</th>
#       <th id="T_1890d_level0_col1" class="col_heading level0 col1" >Question Title</th>
#       <th id="T_1890d_level0_col2" class="col_heading level0 col2" >Nbr of available Choices</th>
#       <th id="T_1890d_level0_col3" class="col_heading level0 col3" >Average number of selected choices</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1890d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1890d_row0_col0" class="data row0 col0" >Q6</td>
#       <td id="T_1890d_row0_col1" class="data row0 col1" >On which platforms have you begun or completed data science courses?</td>
#       <td id="T_1890d_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_1890d_row0_col3" class="data row0 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1890d_row1_col0" class="data row1 col0" >Q7</td>
#       <td id="T_1890d_row1_col1" class="data row1 col1" >What products or platforms did you find to be most helpful when you first
# started studying data science?</td>
#       <td id="T_1890d_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_1890d_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1890d_row2_col0" class="data row2 col0" >Q10</td>
#       <td id="T_1890d_row2_col1" class="data row2 col1" >Did your research make use of machine learning? - Yes, the research made
# advances related to some novel machine learning method (theoretical research)</td>
#       <td id="T_1890d_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_1890d_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1890d_row3_col0" class="data row3 col0" >Q12</td>
#       <td id="T_1890d_row3_col1" class="data row3 col1" >What programming languages do you use on a regular basis?</td>
#       <td id="T_1890d_row3_col2" class="data row3 col2" >15</td>
#       <td id="T_1890d_row3_col3" class="data row3 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1890d_row4_col0" class="data row4 col0" >Q13</td>
#       <td id="T_1890d_row4_col1" class="data row4 col1" >Which of the following integrated development environments (IDE's) do you use on
# a regular basis?</td>
#       <td id="T_1890d_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_1890d_row4_col3" class="data row4 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1890d_row5_col0" class="data row5 col0" >Q14</td>
#       <td id="T_1890d_row5_col1" class="data row5 col1" >Do you use any of the following hosted notebook products?</td>
#       <td id="T_1890d_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_1890d_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1890d_row6_col0" class="data row6 col0" >Q15</td>
#       <td id="T_1890d_row6_col1" class="data row6 col1" >Do you use any of the following data visualization libraries on a regular basis?</td>
#       <td id="T_1890d_row6_col2" class="data row6 col2" >15</td>
#       <td id="T_1890d_row6_col3" class="data row6 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1890d_row7_col0" class="data row7 col0" >Q17</td>
#       <td id="T_1890d_row7_col1" class="data row7 col1" >Which of the following machine learning frameworks do you use on a regular
# basis?</td>
#       <td id="T_1890d_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_1890d_row7_col3" class="data row7 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1890d_row8_col0" class="data row8 col0" >Q18</td>
#       <td id="T_1890d_row8_col1" class="data row8 col1" >Which of the following ML algorithms do you use on a regular basis?</td>
#       <td id="T_1890d_row8_col2" class="data row8 col2" >14</td>
#       <td id="T_1890d_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1890d_row9_col0" class="data row9 col0" >Q19</td>
#       <td id="T_1890d_row9_col1" class="data row9 col1" >Which categories of computer vision methods do you use on a regular basis?</td>
#       <td id="T_1890d_row9_col2" class="data row9 col2" >8</td>
#       <td id="T_1890d_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1890d_row10_col0" class="data row10 col0" >Q20</td>
#       <td id="T_1890d_row10_col1" class="data row10 col1" >Which of the following natural language processing (NLP) methods do you use on a
# regular basis?</td>
#       <td id="T_1890d_row10_col2" class="data row10 col2" >6</td>
#       <td id="T_1890d_row10_col3" class="data row10 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1890d_row11_col0" class="data row11 col0" >Q21</td>
#       <td id="T_1890d_row11_col1" class="data row11 col1" >Do you download pre-trained model weights from any of the following services?</td>
#       <td id="T_1890d_row11_col2" class="data row11 col2" >10</td>
#       <td id="T_1890d_row11_col3" class="data row11 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1890d_row12_col0" class="data row12 col0" >Q28</td>
#       <td id="T_1890d_row12_col1" class="data row12 col1" >Select any activities that make up an important part of your role at work:</td>
#       <td id="T_1890d_row12_col2" class="data row12 col2" >8</td>
#       <td id="T_1890d_row12_col3" class="data row12 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1890d_row13_col0" class="data row13 col0" >Q31</td>
#       <td id="T_1890d_row13_col1" class="data row13 col1" >Which of the following cloud computing platforms do you use?</td>
#       <td id="T_1890d_row13_col2" class="data row13 col2" >12</td>
#       <td id="T_1890d_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1890d_row14_col0" class="data row14 col0" >Q33</td>
#       <td id="T_1890d_row14_col1" class="data row14 col1" >Do you use any of the following cloud computing products?</td>
#       <td id="T_1890d_row14_col2" class="data row14 col2" >5</td>
#       <td id="T_1890d_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1890d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1890d_row15_col0" class="data row15 col0" >Q34</td>
#       <td id="T_1890d_row15_col1" class="data row15 col1" >Do you use any of the following data storage products?</td>
#       <td id
